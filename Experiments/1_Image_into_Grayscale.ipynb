# %%
#1.1 Convert the given Image into Grayscale
import cv2
from google.colab.patches import cv2_imshow
input=cv2.imread('/content/Screenshot 2026-02-26 134721.png')
g_s=cv2.cvtColor(input,cv2.COLOR_BGR2GRAY)
cv2_imshow(g_s)
# Out:
# <PIL.Image.Image image mode=L size=341x193>
